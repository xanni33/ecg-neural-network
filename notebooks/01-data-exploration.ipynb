# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# wczytywanie csv
df = pd.read_csv("../data/raw/ptbxl/ptbxl_database.csv")
df.head()

# opisy scp(rodzaje chorob)
statements = pd.read_csv("../data/raw/ptbxl/scp_statements.csv", index_col=0)
statements.head()

import wfdb

record_path = "../data/raw/ptbxl/records100/00000/00001_hr"
record = wfdb.rdrecord(record_path)
wfdb.plot_wfdb(record, title='Example ECG')
