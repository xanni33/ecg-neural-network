# %% [markdown]
# wczytanie datasetu, dataloader, cnn, trening, walidacja + zapis modelu i wykres

# %%
#setup
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from torch.utils.data import DataLoader

PROJECT_PATH = r"C:\Users\cp\PycharmProjects\ECGmodel"

os.chdir(PROJECT_PATH)

SRC_PATH = os.path.join(PROJECT_PATH, "src")

if SRC_PATH not in sys.path:
    sys.path.append(SRC_PATH)

from ecg_dataset import ECGDataset
from model import ECGCNN

#device
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("device:", device)

#load dataset
train_dataset = ECGDataset(
    "data/processed/X_train_ml.npy",
    "data/processed/y_train_ml.npy"
)

test_dataset = ECGDataset(
    "data/processed/X_test_ml.npy",
    "data/processed/y_test_ml.npy"
)

print(len(train_dataset))
print(len(test_dataset))

from torch.utils.data import random_split

train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size

train_subset, val_subset = random_split(
    train_dataset,
    [train_size, val_size],
    generator=torch.Generator().manual_seed(42)
)

#dataloader
train_loader = DataLoader(
    train_subset,
    batch_size=32,
    shuffle=True
)

val_loader = DataLoader(
    val_subset,
    batch_size=32,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False
)

#model
model = ECGCNN(num_classes=5)

model = model.to(device)

print(model)

#loss + optimizer --------------------------------------------
#criterion = nn.BCEWithLogitsLoss()
y_train = np.load("data/processed/y_train_ml.npy")
class_counts = y_train.sum(axis=0)

total = len(y_train)

pos_weights = total / (2 * class_counts)

print("class counts:", class_counts)
print("pos weights:", pos_weights)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

pos_weights_tensor = torch.tensor(
    pos_weights,
    dtype=torch.float32
).to(device)

criterion = nn.BCEWithLogitsLoss(
    pos_weight=pos_weights_tensor
)
#------------------------------------------------------------------

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

#training loop -> zmiana liczby epok na 30 po zastosowaniu weighted bceloss i early stopppingu aby zapobiec overfittingowi
EPOCHS = 30

train_losses = []

best_val_loss = float("inf")
patience = 5
counter = 0

EPOCHS = 30

train_losses = []
val_losses = []

for epoch in range(EPOCHS):

    # --------------------
    # TRAIN
    # --------------------
    model.train()
    epoch_train_loss = 0

    for X_batch, y_batch in train_loader:

        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()

        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)

        loss.backward()
        optimizer.step()

        epoch_train_loss += loss.item()

    avg_train_loss = epoch_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    # --------------------
    # VAL
    # --------------------
    model.eval()
    epoch_val_loss = 0

    with torch.no_grad():
        for X_batch, y_batch in val_loader:

            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            epoch_val_loss += loss.item()

    avg_val_loss = epoch_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)

    print(
        f"Epoch {epoch+1}/{EPOCHS} | "
        f"Train loss: {avg_train_loss:.4f} | "
        f"Val loss: {avg_val_loss:.4f}"
    )

    # --------------------
    # EARLY STOPPING
    # --------------------
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        counter = 0

        torch.save(model.state_dict(), "models/best_ecg_cnn.pth")

    else:
        counter += 1

        if counter >= patience:
            print("Early stopping triggered!")
            break

#loss plot
plt.figure(figsize=(8,5))
plt.plot(train_losses, label="train")
plt.plot(val_losses, label="val")

plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()


#evaluation - predictions + treshold, model zwraca logity, robie sigmoid i treshold 0.5
model.load_state_dict(torch.load("models/best_ecg_cnn.pth"))
model.eval()

all_preds = []
all_targets = []

with torch.no_grad():

    for X_batch, y_batch in test_loader:

        X_batch = X_batch.to(device)

        outputs = model(X_batch)

        probs = torch.sigmoid(outputs)

        preds = (probs > 0.5).float()

        all_preds.append(preds.cpu())
        all_targets.append(y_batch)


#metrics
from sklearn.metrics import f1_score

y_pred = torch.cat(all_preds).numpy()
y_true = torch.cat(all_targets).numpy()

f1 = f1_score(
    y_true,
    y_pred,
    average="macro"
)

print("F1-score:", f1)

#save model
os.makedirs("models", exist_ok=True)

torch.save(
    model.state_dict(),
    "models/ecg_cnn.pth"
)

print("model saved")
#idea: trenowanie po 500 rekordow, potem 1000, potem 5000, potem 10000, potem cala baza - zeby zobaczyc jak rosnie metryka i czy model sie uczy
# Out:
# device: cpu
# 16000
# 4000
# ECGCNN(
#   (features): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(7,), stride=(1,), padding=(3,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv1d(32, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Dropout(p=0.3, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=11520, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# class counts: [7614. 3553. 3758. 3447. 1888.]
# pos weights: [1.0506961 2.2516184 2.1287918 2.3208587 4.237288 ]
# Epoch 1/30 | Train loss: 0.7961 | Val loss: 0.7372
# Epoch 2/30 | Train loss: 0.7502 | Val loss: 0.7165
# Epoch 3/30 | Train loss: 0.7393 | Val loss: 0.7071
# Epoch 4/30 | Train loss: 0.7305 | Val loss: 0.7124
# Epoch 5/30 | Train loss: 0.7277 | Val loss: 0.7041
# Epoch 6/30 | Train loss: 0.7224 | Val loss: 0.7119
# Epoch 7/30 | Train loss: 0.7213 | Val loss: 0.6922
# Epoch 8/30 | Train loss: 0.7156 | Val loss: 0.7017
# Epoch 9/30 | Train loss: 0.7158 | Val loss: 0.6980
# Epoch 10/30 | Train loss: 0.7135 | Val loss: 0.7220
# Epoch 11/30 | Train loss: 0.7067 | Val loss: 0.6932
# Epoch 12/30 | Train loss: 0.7030 | Val loss: 0.6891
# Epoch 13/30 | Train loss: 0.7028 | Val loss: 0.6870
# Epoch 14/30 | Train loss: 0.7015 | Val loss: 0.7174
# Epoch 15/30 | Train loss: 0.6956 | Val loss: 0.6843
# Epoch 16/30 | Train loss: 0.6922 | Val loss: 0.6842
# Epoch 17/30 | Train loss: 0.6909 | Val loss: 0.6849
# Epoch 18/30 | Train loss: 0.6879 | Val loss: 0.6815
# Epoch 19/30 | Train loss: 0.6842 | Val loss: 0.6822
# Epoch 20/30 | Train loss: 0.6820 | Val loss: 0.6880
# Epoch 21/30 | Train loss: 0.6798 | Val loss: 0.6847
# Epoch 22/30 | Train loss: 0.6790 | Val loss: 0.6863
# Epoch 23/30 | Train loss: 0.6728 | Val loss: 0.6832
# Early stopping triggered!
# F1-score: 0.5260672120796557
# model saved
